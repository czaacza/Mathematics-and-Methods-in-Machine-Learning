# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from surprise import Dataset, Reader, SVD, accuracy
from surprise.model_selection import train_test_split
from collections import defaultdict

# %%
df_anime = pd.read_csv('data/anime.csv', sep=',')
df_ratings = pd.read_csv('data/rating.csv', sep=',')

# %%
df_anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
df_anime.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df_ratings
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %%
df_ratings.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %% [markdown]
# ### Exercise 1
#
# In order to access the Anime title when recommending movies, w are going to merge the anime and rating tables into one DataFrame. We are also going to replace the -1 and 'Unknown' values with NaN, so that these results can be seen by the recommendation algorithm.

# %%
df_anime = df_anime.replace('Unknown', np.nan)
df_anime = df_anime.dropna(how = 'all')
df_anime['type'] = df_anime['type'].fillna('TV')
df_anime['episodes'] = df_anime['episodes'].map(lambda x:np.nan if pd.isnull(x) else int(x))
df_ratings = df_ratings.replace(-1, np.nan)

# %%
df_merged = pd.merge(df_anime, df_ratings, how = 'right', on ='anime_id', suffixes = ['_avg', '_user'])
df_merged.rename(columns = {'rating_user':'user_rating', 'rating_avg':'avg_rating'}, inplace = True)
df_merged
# Out:
#          anime_id                                             name  \
# 0              20                                           Naruto
# 1              24                                    School Rumble
# 2              79                                         Shuffle!
# 3             226                                       Elfen Lied
# 4             241                        Girls Bravo: First Season
# ...           ...                                              ...
# 7813732     16512                   Devil Survivor 2 The Animation
# 7813733     17187  Ghost in the Shell: Arise - Border:1 Ghost Pain
# 7813734     22145                     Kuroshitsuji: Book of Circus
# 7813735       790                                       Ergo Proxy
# 7813736      8074                           Highschool of the Dead
#
#                                                      genre   type  episodes  \
# 0        Action, Comedy, Martial Arts, Shounen, Super P...     TV     220.0
# 1                         Comedy, Romance, School, Shounen     TV      26.0
# 2        Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...     TV      24.0
# 3        Action, Drama, Horror, Psychological, Romance,...     TV      13.0
# 4           Comedy, Ecchi, Fantasy, Harem, Romance, School     TV      11.0
# ...                                                    ...    ...       ...
# 7813732                       Action, Demons, Supernatural     TV      13.0
# 7813733               Mecha, Police, Psychological, Sci-Fi  Movie       1.0
# 7813734  Comedy, Demons, Fantasy, Historical, Shounen, ...     TV      10.0
# 7813735                     Mystery, Psychological, Sci-Fi     TV      23.0
# 7813736                Action, Ecchi, Horror, Supernatural     TV      12.0
#
#          avg_rating   members  user_id  user_rating
# 0              7.81  683297.0        1          NaN
# 1              8.06  178553.0        1          NaN
# 2              7.31  158772.0        1          NaN
# 3              7.85  623511.0        1          NaN
# 4              6.69   84395.0        1          NaN
# ...             ...       ...      ...          ...
# 7813732        7.06  101266.0    73515          7.0
# 7813733        7.64   31747.0    73515          9.0
# 7813734        8.37  122895.0    73515         10.0
# 7813735        8.03  265005.0    73516          9.0
# 7813736        7.46  535892.0    73516          9.0
#
# [7813737 rows x 9 columns]

# %%
# Filter out anime with low ratings
df_merged = df_merged[df_merged['avg_rating'] >= 6]
df_merged
# Out:
#          anime_id                                             name  \
# 0              20                                           Naruto
# 1              24                                    School Rumble
# 2              79                                         Shuffle!
# 3             226                                       Elfen Lied
# 4             241                        Girls Bravo: First Season
# ...           ...                                              ...
# 7813732     16512                   Devil Survivor 2 The Animation
# 7813733     17187  Ghost in the Shell: Arise - Border:1 Ghost Pain
# 7813734     22145                     Kuroshitsuji: Book of Circus
# 7813735       790                                       Ergo Proxy
# 7813736      8074                           Highschool of the Dead
#
#                                                      genre   type  episodes  \
# 0        Action, Comedy, Martial Arts, Shounen, Super P...     TV     220.0
# 1                         Comedy, Romance, School, Shounen     TV      26.0
# 2        Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...     TV      24.0
# 3        Action, Drama, Horror, Psychological, Romance,...     TV      13.0
# 4           Comedy, Ecchi, Fantasy, Harem, Romance, School     TV      11.0
# ...                                                    ...    ...       ...
# 7813732                       Action, Demons, Supernatural     TV      13.0
# 7813733               Mecha, Police, Psychological, Sci-Fi  Movie       1.0
# 7813734  Comedy, Demons, Fantasy, Historical, Shounen, ...     TV      10.0
# 7813735                     Mystery, Psychological, Sci-Fi     TV      23.0
# 7813736                Action, Ecchi, Horror, Supernatural     TV      12.0
#
#          avg_rating   members  user_id  user_rating
# 0              7.81  683297.0        1          NaN
# 1              8.06  178553.0        1          NaN
# 2              7.31  158772.0        1          NaN
# 3              7.85  623511.0        1          NaN
# 4              6.69   84395.0        1          NaN
# ...             ...       ...      ...          ...
# 7813732        7.06  101266.0    73515          7.0
# 7813733        7.64   31747.0    73515          9.0
# 7813734        8.37  122895.0    73515         10.0
# 7813735        8.03  265005.0    73516          9.0
# 7813736        7.46  535892.0    73516          9.0
#
# [7708308 rows x 9 columns]

# %%
# CreateReader object
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset using the Dataset class
data = Dataset.load_from_df(df_merged[['user_id', 'anime_id', 'avg_rating']], reader)

# %%
trainset, testset = train_test_split(data, test_size=.33)

# %% [markdown]
# ### Exercise 2
#
# KNN recommendation algorithm does not perform well when dealing with a dataset this magnitude. The algorithm works fast when dealing with a relatively small number of rows (< 10 000). Fitting the algorithm to a larger amount of data results in obtaining a IOPub data rate exceeded error.
#
# In order to make our recommendation model more efficient, we decided to use SVD algorithm. It seems to successfully handle the entire dataset.

# %%
algo = SVD()
algo.fit(trainset)

# %%
predictions = algo.test(testset)
print(f"RMSE: {accuracy.rmse(predictions)}, MAE: {accuracy.mae(predictions)}")
# Out:
# RMSE: 0.0458
# MAE:  0.0287
# RMSE: 0.04575869695469065, MAE: 0.02869686854076746

# %%
# Find out top 10 recommended anime for user.
def get_top_n(predictions, n=10):

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n = get_top_n(predictions, n=10)

# Print the recommended items for each user
for uid, user_ratings in list(top_n.items())[:5]:
    iname = [iid for (iid, _) in user_ratings]

    print(uid, [iid for (iid, _) in user_ratings])
# Out:
# 51268 [19815, 4224, 4722, 18679, 72, 1943, 227, 517, 11111, 2994]
# 54851 [2904, 431, 1535, 28171, 9989, 16894, 13601, 5341, 11771, 853]
# 42086 [2904, 10087, 205, 4155, 31964, 15323, 121, 8740, 20159, 269]
# 58568 [11061, 2904, 164, 457, 245, 9989, 5028, 170, 7655, 16498]
# 25014 [5114, 9253, 4181, 2904, 263, 1575, 7311, 245, 11741, 1535]

# %%
animename_df = df_anime[['anime_id','name']]
animename_df.head()
# Out:
#    anime_id                              name
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;

# %% [markdown]
# ### Exercises 3
# In order to display the titles of the recommended movies in a meaningful way, we use the merged DataFrame and the code provided on the surprise library documentation page.

# %%
# Find out recommended animes for user

for uid, user_ratings in list(top_n.items())[:10]:
    dic = {"User Id":[], "Recommendation":[]}
    dic["User Id"].append(uid)
    
    for (iid, _) in user_ratings:
        anime_index = animename_df.index[animename_df['anime_id']==iid]
        anime_name = animename_df.iloc[anime_index]['name'].tolist()
        dic["Recommendation"].append(anime_name)

    for uu, ii in dic.items():
        print(uu, ii)
    print("\n")
# Out:
# User Id [51268]
# Recommendation [['No Game No Life'], ['Toradora!'], ['Skip Beat!'], ['Kill la Kill'], ['Full Metal Panic? Fumoffu'], ['Paprika'], ['FLCL'], ['School Rumble Ichi Gakki Hoshuu'], ['Another'], ['Death Note Rewrite']]
#
#
# User Id [54851]
# Recommendation [['Code Geass: Hangyaku no Lelouch R2'], ['Howl no Ugoku Shiro'], ['Death Note'], ['Shokugeki no Souma'], ['Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.'], ['Kuroko no Basket 2nd Season'], ['Psycho-Pass'], ['Ookami to Koushinryou II'], ['Kuroko no Basket'], ['Ouran Koukou Host Club']]
#
#
# User Id [42086]
# Recommendation [['Code Geass: Hangyaku no Lelouch R2'], ['Fate/Zero'], ['Samurai Champloo'], ['One Piece Film: Strong World'], ['Boku no Hero Academia'], ['One Piece: Episode of Nami - Koukaishi no Namida to Nakama no Kizuna'], ['Fullmetal Alchemist'], ['One Piece Film: Strong World Episode 0'], ['Pokemon: The Origin'], ['Bleach']]
#
#
# User Id [58568]
# Recommendation [['Hunter x Hunter (2011)'], ['Code Geass: Hangyaku no Lelouch R2'], ['Mononoke Hime'], ['Mushishi'], ['Great Teacher Onizuka'], ['Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.'], ['Major S5'], ['Slam Dunk'], ['Major S6'], ['Shingeki no Kyojin']]
#
#
# User Id [25014]
# Recommendation [['Fullmetal Alchemist: Brotherhood'], ['Steins;Gate'], ['Clannad: After Story'], ['Code Geass: Hangyaku no Lelouch R2'], ['Hajime no Ippo'], ['Code Geass: Hangyaku no Lelouch'], ['Suzumiya Haruhi no Shoushitsu'], ['Great Teacher Onizuka'], ['Fate/Zero 2nd Season'], ['Death Note']]
#
#
# User Id [35485]
# Recommendation [['Death Note'], ['Chihayafuru 2'], ['Bakuman. 2nd Season'], ['Bakemonogatari'], ['Gin no Saji 2nd Season'], ['InuYasha: Kanketsu-hen'], ['Dragon Ball Z'], ['Kaichou wa Maid-sama!'], ['Fairy Tail'], ['Black Lagoon']]
#
#
# User Id [62775]
# Recommendation [['Fullmetal Alchemist: Brotherhood'], ['Steins;Gate'], ['Code Geass: Hangyaku no Lelouch'], ['Monogatari Series: Second Season'], ['Death Note'], ['Boku dake ga Inai Machi'], ['Re:Zero kara Hajimeru Isekai Seikatsu'], ['Kuroko no Basket 3rd Season'], ['Shokugeki no Souma'], ['Kiseijuu: Sei no Kakuritsu']]
#
#
# User Id [73398]
# Recommendation [['Clannad: After Story'], ['Sen to Chihiro no Kamikakushi'], ['Howl no Ugoku Shiro'], ['Hotaru no Haka'], ['Nichijou'], ['No Game No Life'], ['Toradora!'], ['Natsume Yuujinchou'], ['Danshi Koukousei no Nichijou'], ['Bakuman.']]
#
#
# User Id [33378]
# Recommendation [['Gintama&#039;: Enchousen'], ['Gintama'], ['Sen to Chihiro no Kamikakushi'], ['Mob Psycho 100'], ['Shinsekai yori'], ['Shingeki no Kyojin'], ['Psycho-Pass'], ['Neon Genesis Evangelion: The End of Evangelion'], ['Durarara!!'], ['Danshi Koukousei no Nichijou']]
#
#
# User Id [51876]
# Recommendation [['Clannad: After Story'], ['Fate/Zero 2nd Season'], ['Mahou Shoujo Madoka★Magica Movie 3: Hangyaku no Monogatari'], ['Tsubasa: Tokyo Revelations'], ['Fate/stay night: Unlimited Blade Works 2nd Season'], ['Fate/stay night: Unlimited Blade Works'], ['Cardcaptor Sakura Movie 2: Fuuin Sareta Card'], ['Clannad'], ['Fairy Tail'], ['ef: A Tale of Melodies.']]
